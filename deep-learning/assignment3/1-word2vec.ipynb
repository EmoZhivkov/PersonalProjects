# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3.1
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline

import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'of', 'as', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /Users/ezhivkov/personal-projects/PersonalProjects/deep-learning/assignment2/venv/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:1444: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.148595
# Nearest to five: deleterious, chuvash, myth, veritable, burkert, gazeta, liber, danced,
# Nearest to this: memoir, relates, studi, rainforest, deprecated, hauling, sacramental, desilu,
# Nearest to seven: dxf, sef, dizziness, panics, bethel, grazing, referring, scoreless,
# Nearest to would: kampf, prophetess, franchised, secretions, foy, convey, shyness, nara,
# Nearest to a: homeland, anglicanism, candidates, peacekeepers, pai, excretory, veto, nne,
# Nearest to have: chupacabras, genet, subtleties, mata, eurozone, breakbeat, hessen, knocking,
# Nearest to up: ideal, lactantius, prions, monkey, fold, percentage, jubal, xn,
# Nearest to or: verbs, ferrigno, calico, mestizos, suffered, rbi, hoarding, handguns,
# Nearest to state: oases, punching, stronger, s, jurisdictions, ward, dumping, bees,
# Nearest to if: fets, geezer, rentals, lancet, transport, flickering, calculated, beheaded,
# Nearest to UNK: recognise, tokugawa, muscular, creator, bolshevism, nta, unaccented, robespierre,
# Nearest to years: whistling, laminal, bronson, interim, multicast, elmer, sailor, grounding,
# Nearest to so: voluntarily, male, rebellious, grbac, epictetus, acronyms, gustloff, alene,
# Nearest to there: recessive, knesset, requirements, repopulated, persists, graecia, menial, software,
# Nearest to also: transhuman, larnaca, bringing, restricted, allowable, active, thatcherism, immature,
# Nearest to during: gate, xyz, manoeuvre, heckler, scripts, axiomatic, fewest, pounding,
# Average loss at step 2000: 4.369650
# Average loss at step 4000: 3.873013
# Average loss at step 6000: 3.793068
# Average loss at step 8000: 3.691088
# Average loss at step 10000: 3.616965
# Nearest to five: six, four, three, eight, seven, nine, two, zero,
# Nearest to this: it, the, a, which, their, hippopotamus, rationalisation, his,
# Nearest to seven: six, three, nine, eight, five, four, zero, two,
# Nearest to would: will, can, prophetess, might, must, nara, tone, pmod,
# Nearest to a: the, this, runoff, trio, born, phosphates, approaching, transformed,
# Nearest to have: had, has, be, are, superheroic, do, were, heterotic,
# Nearest to up: zarathustra, percentage, pia, rinsing, belarus, xn, forehead, todd,
# Nearest to or: and, fare, hashshashin, mort, for, manifolds, ribosomes, waned,
# Nearest to state: oases, government, stronger, rang, punching, soul, antique, soviet,
# Nearest to if: does, fets, jam, rentals, lancet, stumbled, calculated, dissent,
# Nearest to UNK: metropolis, authorizes, gordie, tidal, feng, hemingway, ackermann, kingdom,
# Nearest to years: reintroduce, settlement, rossetti, carmichael, scourge, february, landfill, gustavus,
# Nearest to so: voluntarily, players, speeds, digraph, protease, roundabout, male, darboux,
# Nearest to there: it, recessive, they, he, requirements, basayev, sometimes, also,
# Nearest to also: still, shigeru, larnaca, not, transhuman, often, which, fortran,
# Nearest to during: in, realise, axiomatic, rel, first, hydrothermal, riigikogu, by,
# Average loss at step 12000: 3.605892
# Average loss at step 14000: 3.570504
# Average loss at step 16000: 3.409644
# Average loss at step 18000: 3.456027
# Average loss at step 20000: 3.543207
# Nearest to five: six, three, seven, four, eight, zero, two, nine,
# Nearest to this: it, which, the, rationalisation, his, that, their, its,
# Nearest to seven: six, eight, five, nine, three, four, two, zero,
# Nearest to would: will, can, could, must, may, might, should, to,
# Nearest to a: the, any, advocacy, transformed, this, runoff, phosphates, no,
# Nearest to have: had, has, were, be, are, superheroic, lombard, heterotic,
# Nearest to up: him, zarathustra, their, percentage, out, wastes, back, pia,
# Nearest to or: and, than, mort, pandora, efficient, mchale, aspiration, ribosomes,
# Nearest to state: oases, government, congress, rang, stronger, diffie, clergy, antique,
# Nearest to if: but, when, jam, does, stumbled, bituminous, fets, gives,
# Nearest to UNK: flirt, dsp, mutually, unusually, safe, participatory, reviving, hot,
# Nearest to years: settlement, times, reintroduce, rossetti, neustadt, characters, months, sundance,
# Nearest to so: voluntarily, players, restored, formerly, darboux, speeds, digraph, protease,
# Nearest to there: it, they, he, which, heron, sponge, recessive, software,
# Nearest to also: which, now, not, still, often, stakeholders, fortran, gaff,
# Nearest to during: in, realise, axiomatic, from, at, hydrothermal, following, after,
# Average loss at step 22000: 3.498758
# Average loss at step 24000: 3.492836
# Average loss at step 26000: 3.481518
# Average loss at step 28000: 3.483146
# Average loss at step 30000: 3.501775
# Nearest to five: four, seven, eight, six, three, nine, zero, two,
# Nearest to this: it, which, that, substitutes, beaulieu, what, wozniak, envelopes,
# Nearest to seven: five, eight, three, four, nine, six, zero, two,
# Nearest to would: will, can, could, may, must, might, should, to,
# Nearest to a: any, runoff, the, phosphates, ifv, approaching, hashshashin, scruggs,
# Nearest to have: had, has, were, be, are, having, superheroic, lombard,
# Nearest to up: him, them, out, percentage, zarathustra, back, analytic, centripetal,
# Nearest to or: and, ribosomes, swordsman, than, mormonism, loon, but, manifolds,
# Nearest to state: government, congress, oases, antique, rise, rang, ban, narcissus,
# Nearest to if: when, is, gives, stumbled, does, sant, moabite, fets,
# Nearest to UNK: hieroglyphic, indomitable, et, developer, condominiums, philosopher, suffocation, unwelcome,
# Nearest to years: times, months, settlement, year, weeks, reintroduce, rossetti, characters,
# Nearest to so: voluntarily, restored, isthmus, formerly, ain, constructed, speeds, darboux,
# Nearest to there: they, it, he, heron, often, usually, we, which,
# Nearest to also: now, often, still, gaff, stakeholders, which, fortran, always,
# Nearest to during: in, after, at, when, realise, with, from, despite,
# Average loss at step 32000: 3.499642
# Average loss at step 34000: 3.494507
# Average loss at step 36000: 3.452772
# Average loss at step 38000: 3.303883
# Average loss at step 40000: 3.429674
# Nearest to five: seven, four, six, three, eight, nine, zero, two,
# Nearest to this: which, it, the, that, what, tonle, substitutes, destabilization,
# Nearest to seven: six, five, eight, nine, four, three, zero, two,
# Nearest to would: will, could, can, may, must, might, should, did,
# Nearest to a: the, another, phosphates, any, veto, ilya, strumming, bickering,
# Nearest to have: had, has, were, be, are, find, bribery, lombard,
# Nearest to up: him, them, out, zarathustra, back, percentage, analytic, down,
# Nearest to or: and, than, coexistence, contingents, ribosomes, any, stovl, berenson,
# Nearest to state: government, congress, oases, rise, honed, ward, stronger, parlour,
# Nearest to if: when, where, is, gives, stumbled, fets, sant, because,
# Nearest to UNK: b, j, russian, johnson, dsp, d, phage, lakeside,
# Nearest to years: months, times, weeks, year, settlement, rossetti, characters, cahokia,
# Nearest to so: ain, isthmus, repainted, formerly, tubas, panther, humiliation, constructed,
# Nearest to there: it, they, he, usually, which, often, sometimes, she,
# Nearest to also: often, which, still, now, usually, generally, actually, who,
# Nearest to during: after, from, in, at, when, through, realise, before,
# Average loss at step 42000: 3.438248
# Average loss at step 44000: 3.453955
# Average loss at step 46000: 3.450780
# Average loss at step 48000: 3.352719
# Average loss at step 50000: 3.387691
# Nearest to five: four, seven, six, eight, three, nine, zero, two,
# Nearest to this: which, it, the, beaulieu, reformulation, tonle, upcoming, hides,
# Nearest to seven: six, eight, four, nine, three, five, zero, two,
# Nearest to would: could, will, can, may, must, might, should, did,
# Nearest to a: the, another, runoff, anglicanism, magyars, any, pai, phosphates,
# Nearest to have: had, has, were, be, are, superheroic, having, receivers,
# Nearest to up: them, out, him, zarathustra, down, back, off, analytic,
# Nearest to or: and, than, but, scandinavians, heliocentric, browsing, ribosomes, albinus,
# Nearest to state: government, congress, oases, honed, kingdom, adolf, parlour, stronger,
# Nearest to if: when, where, although, sant, stumbled, since, though, but,
# Nearest to UNK: de, et, modeling, hashes, springsteen, spree, ludwig, propensity,
# Nearest to years: months, times, year, days, weeks, rossetti, characters, settlement,
# Nearest to so: bonewits, then, ain, constructed, brooker, tubas, vara, stylish,
# Nearest to there: they, it, he, often, she, now, usually, sometimes,
# Nearest to also: often, now, which, still, generally, provocative, largely, stakeholders,
# Nearest to during: in, after, from, when, at, through, for, where,
# Average loss at step 52000: 3.440667
# Average loss at step 54000: 3.426716
# Average loss at step 56000: 3.445033
# Average loss at step 58000: 3.401201
# Average loss at step 60000: 3.395868
# Nearest to five: six, four, eight, three, seven, zero, nine, two,
# Nearest to this: which, it, that, some, the, there, kurosawa, a,
# Nearest to seven: eight, four, six, nine, five, three, zero, two,
# Nearest to would: could, will, can, may, must, might, should, did,
# Nearest to a: the, another, any, ilya, every, this, runoff, magyars,
# Nearest to have: had, has, were, are, be, having, provide, lombard,
# Nearest to up: out, them, him, off, down, back, zarathustra, analytic,
# Nearest to or: and, than, revitalization, scandinavians, but, ribosomes, bruton, contingents,
# Nearest to state: government, kingdom, majority, states, parlour, congress, rise, rest,
# Nearest to if: when, where, because, though, before, although, since, really,
# Nearest to UNK: ariel, facto, carbon, takashi, confronting, csa, accountability, nationality,
# Nearest to years: months, times, days, weeks, year, decades, people, settlement,
# Nearest to so: ain, too, bonewits, even, then, restored, more, polio,
# Nearest to there: they, it, now, often, she, he, still, usually,
# Nearest to also: now, often, generally, still, actually, usually, which, always,
# Nearest to during: after, in, before, when, following, despite, although, at,
# Average loss at step 62000: 3.245634
# Average loss at step 64000: 3.255002
# Average loss at step 66000: 3.406062
# Average loss at step 68000: 3.395249
# Average loss at step 70000: 3.362490
# Nearest to five: six, four, three, seven, eight, zero, nine, two,
# Nearest to this: which, it, that, another, the, some, there, substitutes,
# Nearest to seven: six, four, eight, nine, five, three, zero, one,
# Nearest to would: could, will, can, may, must, might, should, did,
# Nearest to a: the, another, any, magyars, ilya, phosphates, elaine, runoff,
# Nearest to have: had, has, were, are, provide, superheroic, be, having,
# Nearest to up: out, off, them, back, down, him, analytic, percentage,
# Nearest to or: and, than, while, any, revitalization, but, like, interdisciplinarity,
# Nearest to state: government, university, states, kingdom, city, congress, acupuncture, soviets,
# Nearest to if: when, where, though, because, while, before, although, for,
# Nearest to UNK: unattractive, supremely, jesse, oh, tonal, bush, sedative, albury,
# Nearest to years: months, days, times, weeks, decades, year, bc, catalogs,
# Nearest to so: ain, sometimes, even, glu, constructed, restored, then, if,
# Nearest to there: they, it, he, now, generally, we, still, often,
# Nearest to also: now, often, which, still, usually, sometimes, commonly, generally,
# Nearest to during: after, before, in, following, through, despite, until, since,
# Average loss at step 72000: 3.374184
# Average loss at step 74000: 3.348782
# Average loss at step 76000: 3.318873
# Average loss at step 78000: 3.355034
# Average loss at step 80000: 3.381624
# Nearest to five: six, four, eight, seven, three, nine, zero, two,
# Nearest to this: which, it, another, there, rationalisation, beaulieu, that, the,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to would: could, will, can, might, may, must, should, did,
# Nearest to a: another, the, phosphates, keswick, every, transformed, runoff, magyars,
# Nearest to have: had, has, were, are, be, include, having, provide,
# Nearest to up: off, out, back, down, them, him, zarathustra, percentage,
# Nearest to or: and, than, mort, ribosomes, while, nationalistic, but, ablaut,
# Nearest to state: government, kingdom, city, pennsylvania, council, acupuncture, harum, states,
# Nearest to if: when, though, where, before, because, although, then, since,
# Nearest to UNK: dr, johnson, van, wilson, von, juan, emptiness, embezzlement,
# Nearest to years: months, days, weeks, times, decades, year, hours, centuries,
# Nearest to so: constructed, if, ensign, then, polio, brooker, glu, however,
# Nearest to there: they, it, he, she, generally, we, this, now,
# Nearest to also: now, often, which, sometimes, still, commonly, actually, never,
# Nearest to during: after, before, in, when, despite, through, following, until,
# Average loss at step 82000: 3.409357
# Average loss at step 84000: 3.414189
# Average loss at step 86000: 3.391727
# Average loss at step 88000: 3.352693
# Average loss at step 90000: 3.364194
# Nearest to five: eight, three, seven, four, six, nine, two, zero,
# Nearest to this: it, which, another, the, itself, any, substitutes, some,
# Nearest to seven: eight, five, nine, four, six, three, one, zero,
# Nearest to would: could, will, might, may, can, must, should, did,
# Nearest to a: another, any, the, keswick, ghibellines, every, borer, ilya,
# Nearest to have: had, has, were, are, be, superheroic, provide, having,
# Nearest to up: off, out, back, down, them, him, together, zarathustra,
# Nearest to or: and, including, than, cc, ribosomes, des, fare, cowes,
# Nearest to state: government, council, city, acupuncture, kingdom, pennsylvania, sportsmanship, parlour,
# Nearest to if: when, where, though, before, without, although, after, because,
# Nearest to UNK: dte, ladino, anacharsis, bush, coles, dactyl, und, trapper,
# Nearest to years: days, months, decades, weeks, times, year, hours, centuries,
# Nearest to so: if, brooker, too, thus, ornate, vara, later, desk,
# Nearest to there: they, it, he, she, still, we, generally, now,
# Nearest to also: now, often, which, still, never, sometimes, actually, commonly,
# Nearest to during: after, in, before, while, until, when, despite, through,
# Average loss at step 92000: 3.395857
# Average loss at step 94000: 3.256171
# Average loss at step 96000: 3.363446
# Average loss at step 98000: 3.245487
# Average loss at step 100000: 3.360231
# Nearest to five: four, seven, six, eight, three, zero, nine, two,
# Nearest to this: it, which, another, some, qq, guildhall, the, itself,
# Nearest to seven: eight, six, five, four, nine, three, two, zero,
# Nearest to would: could, will, might, may, should, can, must, did,
# Nearest to a: another, the, any, unbroken, anglicanism, keswick, werke, toba,
# Nearest to have: had, has, are, be, having, were, superheroic, provide,
# Nearest to up: off, out, back, them, him, down, together, zarathustra,
# Nearest to or: and, than, per, ribosomes, varphi, punishments, asymmetrical, while,
# Nearest to state: government, city, council, acupuncture, pennsylvania, kingdom, congress, harum,
# Nearest to if: when, though, where, without, before, therefore, although, because,
# Nearest to UNK: succeeding, reintegrated, developer, flawless, idf, synthesizing, lorenzo, phenomenal,
# Nearest to years: days, months, weeks, decades, year, times, hours, centuries,
# Nearest to so: too, thus, if, later, when, desk, then, brooker,
# Nearest to there: they, he, it, we, she, generally, often, still,
# Nearest to also: now, actually, still, never, often, sometimes, generally, which,
# Nearest to during: after, in, before, when, despite, until, through, within,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels


batch, labels = generate_batch(8, 1)
for i in range(8):
    print(batch[i, 0], reverse_dictionary[batch[i, 0]],
          batch[i, 1], reverse_dictionary[batch[i, 1]],
          '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 214 ii 2 of -> 757 lord
# 757 lord 2187 destruction -> 2 of
# 2 of 0 UNK -> 2187 destruction
# 2187 destruction 12908 persist -> 0 UNK
# 0 UNK 14 for -> 12908 persist
# 12908 persist 12 as -> 14 for
# 14 for 185 long -> 12 as
# 12 as 12 as -> 185 long

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
context_window = 1  # How many words to consider left and right.
context_size = 2 * context_window

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():
    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size, context_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)
        # take mean of embeddings of context words for context embedding
        embed_context = tf.reduce_mean(embed, 1)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
        tf.nn.nce_loss(nce_weights, nce_biases, train_labels, embed_context,
                       num_sampled, vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)

    valid_embeddings = tf.cast(valid_embeddings, tf.float32)
    similarity = tf.matmul(
        valid_embeddings, tf.transpose(normalized_embeddings))

    # Add variable initializer.
    init = tf.initialize_all_variables()

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, context_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "Nearest to %s:" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  257.89508056640625
# Nearest to such: bacteria, precedes, universidad, letting, ceasing, bored, campo, present,
# Nearest to this: objectionable, admittedly, saint, carbon, pikes, icj, mistakes, breaded,
# Nearest to b: trying, purana, label, saginaw, nugget, nazareth, offensive, flocks,
# Nearest to four: effecting, svante, leprosy, appreciated, elevate, vulcan, sakai, tweed,
# Nearest to he: rainbows, folkloric, observant, gorey, inhale, tierra, cabaret, participates,
# Nearest to an: statue, connolly, emerald, pasadena, journ, converges, naur, hath,
# Nearest to its: restraining, starter, chilled, pasted, simplifications, lingo, gallium, meteors,
# Nearest to with: lectured, serenity, extends, blockade, auditions, menial, epirus, nomenclature,
# Nearest to in: mood, powders, diligently, prevailing, havenco, mottled, osiris, dismemberment,
# Nearest to two: ld, illustration, ge, concerti, hiss, raised, scarlett, encapsulated,
# Nearest to into: prd, broadcaster, chosenness, garand, maryam, laban, knit, tips,
# Nearest to no: varela, flywheels, vapour, bd, funerary, cricketers, extensions, mesa,
# Nearest to six: enya, briefcase, disambiguate, sukarnoputri, geo, reverted, rejuvenation, yemeni,
# Nearest to system: hildesheim, trams, unrest, revisionism, habitations, manifestations, terrence, hasidim,
# Nearest to after: lerner, galley, mhz, burton, daw, artery, algirdas, paragraphs,
# Nearest to five: compromised, spoofs, phospholipid, grave, superfund, arminius, supplements, cyan,
# Average loss at step  2000 :  107.76477229118348
# Average loss at step  4000 :  49.09232675766945
# Average loss at step  6000 :  29.67989874768257
# Average loss at step  8000 :  21.047160704016687
# Average loss at step  10000 :  15.801687519550324
# Nearest to such: known, bacteria, lucy, elbl, countries, present, singer, datura,
# Nearest to this: one, which, a, joe, detroit, the, magic, carbon,
# Nearest to b: trying, duke, label, written, byers, usually, earl, william,
# Nearest to four: eight, nine, business, seven, article, per, electron, zero,
# Nearest to he: it, who, they, you, young, maps, werner, pieces,
# Nearest to an: the, statue, speech, letter, its, largely, hall, business,
# Nearest to its: an, the, guinea, included, hence, goal, interest, europe,
# Nearest to with: by, song, for, and, through, uk, helped, strong,
# Nearest to in: at, from, prevailing, port, on, after, during, into,
# Nearest to two: one, raised, classical, level, three, smells, ge, UNK,
# Nearest to into: datura, exists, through, face, drink, structure, ericsson, should,
# Nearest to no: bioko, directed, successful, extensions, datura, result, creating, children,
# Nearest to six: eight, r, kabul, killed, chance, depicts, liberal, terrier,
# Nearest to system: through, derry, datura, won, accept, griswold, our, colony,
# Nearest to after: summer, in, parton, peter, under, mhz, burton, seuss,
# Nearest to five: nine, zero, eight, datura, daleks, claims, buildings, market,
# Average loss at step  12000 :  12.167729982495308
# Average loss at step  14000 :  9.917377201318741
# Average loss at step  16000 :  8.36005684041977
# Average loss at step  18000 :  7.736780823469162
# Average loss at step  20000 :  6.76054490673542
# Nearest to such: known, lucy, bacteria, elbl, concentrated, well, edmund, mixing,
# Nearest to this: which, the, joe, what, one, detroit, carbon, mistakes,
# Nearest to b: trying, label, ceiling, byers, killing, duke, offensive, delta,
# Nearest to four: eight, seven, six, per, zero, nine, three, equus,
# Nearest to he: it, they, who, she, you, squadron, young, maps,
# Nearest to an: statue, the, speech, its, largely, econometrics, prohibition, pronunciation,
# Nearest to its: the, an, guinea, his, creed, lawsuit, interest, europe,
# Nearest to with: song, through, by, for, uk, helped, strong, nomenclature,
# Nearest to in: at, from, prevailing, during, on, appointment, after, into,
# Nearest to two: one, three, etna, raised, seven, smells, eight, six,
# Nearest to into: through, drink, exists, toronto, about, leo, in, face,
# Nearest to no: bioko, successful, directed, creating, a, extensions, patterns, any,
# Nearest to six: eight, five, nine, zero, three, kabul, four, killed,
# Nearest to system: griswold, derry, accept, trams, through, our, rank, commentary,
# Nearest to after: under, burton, summer, mhz, before, in, porcelain, barb,
# Nearest to five: eight, nine, six, zero, danio, three, datura, barb,
# Average loss at step  22000 :  6.300647332787514
# Average loss at step  24000 :  5.781097056925296
# Average loss at step  26000 :  5.77516286790371
# Average loss at step  28000 :  5.506643138885498
# Average loss at step  30000 :  5.210698321580887
# Nearest to such: known, lucy, well, many, concentrated, bacteria, mixing, elbl,
# Nearest to this: which, what, joe, clearer, the, one, mistakes, representations,
# Nearest to b: trying, UNK, label, offensive, killing, ceiling, byers, delta,
# Nearest to four: eight, seven, six, five, three, nine, equus, zero,
# Nearest to he: it, she, they, who, you, later, squadron, ontario,
# Nearest to an: statue, its, the, largely, speech, gibraltar, econometrics, superseded,
# Nearest to its: the, his, their, lawsuit, an, them, cape, cottage,
# Nearest to with: song, through, nomenclature, uk, during, for, by, projection,
# Nearest to in: at, during, on, prevailing, from, appointment, under, beaten,
# Nearest to two: one, three, five, four, stadtbahn, etna, eight, several,
# Nearest to into: through, drink, structure, exists, toronto, rez, nevis, laban,
# Nearest to no: bioko, successful, a, any, painted, sack, op, vapour,
# Nearest to six: eight, nine, four, five, three, zero, seven, kabul,
# Nearest to system: griswold, accept, derry, execute, trams, lynx, our, manifestations,
# Nearest to after: under, before, burton, mhz, summer, last, during, island,
# Nearest to five: eight, nine, four, six, three, zero, two, danio,
# Average loss at step  32000 :  5.191018686890602
# Average loss at step  34000 :  5.058428644418717
# Average loss at step  36000 :  4.961341614603996
# Average loss at step  38000 :  4.92366360449791
# Average loss at step  40000 :  4.674898546457291
# Nearest to such: known, lucy, many, well, seen, specifying, concentrated, mixing,
# Nearest to this: which, what, the, clearer, mistakes, representations, magic, joe,
# Nearest to b: trying, offensive, william, d, ceiling, label, killing, delta,
# Nearest to four: eight, five, six, seven, three, nine, zero, bde,
# Nearest to he: it, she, they, who, later, squadron, you, multiplied,
# Nearest to an: the, statue, largely, rosslyn, gibraltar, superseded, econometrics, shogunate,
# Nearest to its: the, his, their, lawsuit, them, cape, dewey, her,
# Nearest to with: song, through, nomenclature, lectured, epirus, carroll, whitey, sprang,
# Nearest to in: during, at, on, prevailing, within, under, appointment, against,
# Nearest to two: three, one, four, bde, etna, stadtbahn, six, five,
# Nearest to into: through, laban, structure, nevis, drink, toronto, rez, main,
# Nearest to no: bioko, any, vapour, painted, sack, a, done, successful,
# Nearest to six: eight, four, five, nine, zero, seven, three, bde,
# Nearest to system: griswold, derry, accept, execute, hildesheim, manifestations, trams, lynx,
# Nearest to after: before, under, burton, during, mhz, against, porcelain, last,
# Nearest to five: four, six, eight, three, bde, nine, zero, seven,
# Average loss at step  42000 :  4.718072198152542
# Average loss at step  44000 :  4.697286806225777
# Average loss at step  46000 :  4.5506824140548705
# Average loss at step  48000 :  4.26835430431366
# Average loss at step  50000 :  4.372448771357536
# Nearest to such: known, lucy, many, well, seen, specifying, concentrated, mixing,
# Nearest to this: which, what, clearer, it, mistakes, the, representations, acoustic,
# Nearest to b: d, trying, offensive, ceiling, challenges, byers, killing, debts,
# Nearest to four: six, five, eight, seven, three, nine, zero, bde,
# Nearest to he: it, she, they, who, later, squadron, yamamoto, eventually,
# Nearest to an: shogunate, largely, statue, rosslyn, yyyy, upwelling, superseded, prohibition,
# Nearest to its: his, the, their, lawsuit, her, dewey, bde, them,
# Nearest to with: song, through, nomenclature, lectured, epirus, sprang, degeneration, whitey,
# Nearest to in: during, at, within, against, from, on, prevailing, chorus,
# Nearest to two: three, four, bde, five, six, stadtbahn, seven, eight,
# Nearest to into: through, laban, nevis, structure, rez, to, main, coronado,
# Nearest to no: any, bioko, vapour, nine, painted, sack, nnhilde, done,
# Nearest to six: eight, four, five, nine, seven, three, zero, bde,
# Nearest to system: griswold, derry, accept, execute, manifestations, medical, lynx, federation,
# Nearest to after: before, under, during, burton, mhz, last, porcelain, against,
# Nearest to five: four, six, eight, nine, seven, three, zero, bde,
# Average loss at step  52000 :  4.481195675253868
# Average loss at step  54000 :  4.486930949091911
# Average loss at step  56000 :  4.588098996758461
# Average loss at step  58000 :  4.460576699972153
# Average loss at step  60000 :  4.350780958414078
# Nearest to such: known, lucy, many, well, seen, these, specifying, geography,
# Nearest to this: which, what, the, it, clearer, mistakes, that, representations,
# Nearest to b: d, trying, offensive, ceiling, challenges, n, plates, debts,
# Nearest to four: five, six, seven, eight, three, rajonas, UNK, nine,
# Nearest to he: she, it, they, who, later, eventually, squadron, yamamoto,
# Nearest to an: shogunate, largely, upwelling, rosslyn, concur, amazons, clade, yyyy,
# Nearest to its: their, his, the, her, lawsuit, cape, bisexual, dewey,
# Nearest to with: song, through, lectured, nomenclature, whitey, degeneration, epirus, sprang,
# Nearest to in: during, at, within, on, throughout, under, appointment, prevailing,
# Nearest to two: three, four, five, one, six, seven, bde, rajonas,
# Nearest to into: through, laban, nevis, structure, coronado, rez, nelson, datura,
# Nearest to no: any, fripp, bioko, sack, vapour, nnhilde, painted, taboo,
# Nearest to six: eight, four, five, seven, nine, rajonas, three, UNK,
# Nearest to system: accept, derry, griswold, manifestations, execute, trams, engineering, hildesheim,
# Nearest to after: before, under, during, burton, porcelain, mhz, despite, martians,
# Nearest to five: four, six, eight, seven, three, rajonas, nine, bde,
# Average loss at step  62000 :  4.524620622754097
# Average loss at step  64000 :  4.474048083543777
# Average loss at step  66000 :  4.39763490831852
# Average loss at step  68000 :  4.119192492723465
# Average loss at step  70000 :  4.298852742314339
# Nearest to such: known, many, lucy, well, these, seen, including, specifying,
# Nearest to this: which, it, what, the, clearer, mistakes, that, representations,
# Nearest to b: d, trying, ceiling, challenges, offensive, plates, n, debts,
# Nearest to four: five, seven, six, eight, three, rajonas, factum, rajons,
# Nearest to he: she, it, they, who, eventually, later, yamamoto, frederik,
# Nearest to an: largely, shogunate, upwelling, amazons, fripp, rosslyn, clade, concur,
# Nearest to its: their, the, his, her, lawsuit, dewey, pinkish, cape,
# Nearest to with: lectured, song, nomenclature, whitey, through, degeneration, epirus, between,
# Nearest to in: during, within, at, throughout, beaten, on, under, chorus,
# Nearest to two: three, four, five, six, seven, bde, rajons, rajonas,
# Nearest to into: through, laban, nevis, coronado, structure, nelson, distinctive, rez,
# Nearest to no: any, fripp, bioko, vapour, nnhilde, painted, sack, taboo,
# Nearest to six: eight, four, seven, five, nine, rajonas, three, factum,
# Nearest to system: accept, manifestations, execute, derry, systems, griswold, engineering, trams,
# Nearest to after: before, under, during, burton, despite, martians, porcelain, mhz,
# Nearest to five: four, six, eight, seven, three, rajonas, nine, bde,
# Average loss at step  72000 :  4.215333791971207
# Average loss at step  74000 :  4.351229372620582
# Average loss at step  76000 :  4.270728310465812
# Average loss at step  78000 :  4.315191065430641
# Average loss at step  80000 :  4.262518172502518
# Nearest to such: known, many, these, lucy, well, seen, including, specifying,
# Nearest to this: which, it, what, clearer, that, the, mistakes, representations,
# Nearest to b: d, trying, challenges, offensive, ceiling, plates, n, debts,
# Nearest to four: five, seven, eight, six, three, rajonas, nine, factum,
# Nearest to he: she, it, they, who, eventually, yamamoto, later, never,
# Nearest to an: shogunate, largely, upwelling, rosslyn, clade, pasadena, concur, fripp,
# Nearest to its: their, his, the, her, lawsuit, dewey, pinkish, prophylaxis,
# Nearest to with: song, lectured, between, whitey, through, nomenclature, degeneration, sprang,
# Nearest to in: during, within, at, throughout, on, under, beaten, among,
# Nearest to two: three, four, five, one, six, rajons, factum, rajonas,
# Nearest to into: through, laban, nevis, coronado, around, nelson, distinctive, structure,
# Nearest to no: any, fripp, nnhilde, bioko, vapour, painted, taboo, enroll,
# Nearest to six: eight, seven, five, four, nine, rajonas, three, factum,
# Nearest to system: manifestations, execute, derry, systems, accept, griswold, engineering, state,
# Nearest to after: before, during, under, burton, despite, martians, porcelain, mhz,
# Nearest to five: four, seven, eight, six, three, nine, rajonas, bde,
# Average loss at step  82000 :  4.254442046523094
# Average loss at step  84000 :  4.18090369105339
# Average loss at step  86000 :  4.223435833454132
# Average loss at step  88000 :  4.138308965682984
# Average loss at step  90000 :  4.20468328654766
# Nearest to such: known, these, many, lucy, well, including, seen, hj,
# Nearest to this: which, it, what, clearer, mistakes, the, that, representations,
# Nearest to b: d, challenges, trying, ceiling, plates, offensive, writer, debts,
# Nearest to four: five, six, eight, seven, three, rajonas, two, factum,
# Nearest to he: she, it, they, who, eventually, yamamoto, there, never,
# Nearest to an: largely, shogunate, amazons, upwelling, fripp, superseded, pasadena, concur,
# Nearest to its: their, his, the, her, lawsuit, dewey, prophylaxis, pinkish,
# Nearest to with: lectured, between, whitey, song, sprang, through, degeneration, quaternary,
# Nearest to in: during, within, at, throughout, on, under, beaten, among,
# Nearest to two: three, four, six, eight, five, rajons, factum, rajonas,
# Nearest to into: through, laban, nevis, around, coronado, distinctive, nelson, keating,
# Nearest to no: any, fripp, nnhilde, painted, bioko, vapour, taboo, enroll,
# Nearest to six: eight, seven, five, four, nine, rajonas, three, factum,
# Nearest to system: systems, manifestations, execute, derry, accept, griswold, engineering, state,
# Nearest to after: before, during, under, despite, burton, martians, porcelain, mhz,
# Nearest to five: four, six, seven, eight, three, rajonas, nine, bde,
# Average loss at step  92000 :  4.179129261136055
# Average loss at step  94000 :  4.230821084737777
# Average loss at step  96000 :  4.193010288119316
# Average loss at step  98000 :  4.047344721078873
# Average loss at step  100000 :  4.177618604779243
# Nearest to such: these, many, known, lucy, including, seen, well, hj,
# Nearest to this: which, it, what, clearer, the, mistakes, that, representations,
# Nearest to b: d, challenges, trying, ceiling, vla, plates, offensive, n,
# Nearest to four: five, six, three, seven, eight, rajonas, two, factum,
# Nearest to he: she, it, they, who, eventually, there, never, yamamoto,
# Nearest to an: largely, shogunate, upwelling, amazons, concur, neuro, clade, rosslyn,
# Nearest to its: their, his, the, her, pinkish, lawsuit, dewey, prophylaxis,
# Nearest to with: lectured, between, song, sprang, whitey, hutton, quaternary, nomenclature,
# Nearest to in: during, within, throughout, at, on, under, among, prevailing,
# Nearest to two: three, four, six, five, one, bde, rajons, factum,
# Nearest to into: through, laban, coronado, nevis, around, nelson, distinctive, from,
# Nearest to no: any, fripp, nnhilde, painted, taboo, vapour, bioko, nine,
# Nearest to six: seven, four, eight, five, three, nine, rajonas, factum,
# Nearest to system: systems, manifestations, execute, derry, accept, engineering, passport, seashore,
# Nearest to after: before, during, under, despite, burton, martians, when, until,
# Nearest to five: four, six, seven, eight, three, rajonas, bde, factum,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
