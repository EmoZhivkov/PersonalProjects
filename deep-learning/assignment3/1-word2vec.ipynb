# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3.1
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline

import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /Users/ezhivkov/personal-projects/PersonalProjects/deep-learning/assignment2/venv/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/ezhivkov/personal-projects/PersonalProjects/deep-learning/assignment2/venv/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:1444: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /Users/ezhivkov/personal-projects/PersonalProjects/deep-learning/assignment2/venv/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.173181
# Nearest to two: pr, postcode, mania, metastable, werner, tito, casein, pratt,
# Nearest to however: unspeakable, scaffold, ensures, criminology, nightfall, venues, alumni, bouillon,
# Nearest to known: biochemical, disparaging, partitioned, pluralistic, knobs, gladio, demobilization, chih,
# Nearest to as: reproduce, sangha, sideband, agreements, supergroup, ewe, baptised, bennington,
# Nearest to is: es, tubes, tangent, venizelos, skynyrd, pear, teletext, unworkable,
# Nearest to the: zionists, frodo, hearth, prefers, forster, scytale, unproven, importance,
# Nearest to has: comrie, relaunched, kosova, hamito, romana, winter, sturgeon, expansionary,
# Nearest to up: asceticism, undeclared, axle, magnificence, piloted, dispose, product, holiday,
# Nearest to time: guerrero, grantham, css, hessen, captivity, rubicon, woodwinds, stiff,
# Nearest to at: differently, rams, embryogenesis, pulsation, paulus, laughton, humpback, soba,
# Nearest to not: conquers, interconnected, mondeo, prions, maury, mammoths, resource, comnena,
# Nearest to d: polyphonic, cuba, cram, seth, catalyst, electroacoustic, listerine, hesychastic,
# Nearest to were: acquis, mesoplodon, brothers, deficit, impairment, clip, hypomanic, bernardino,
# Nearest to american: retribution, poorer, indulgent, toolbox, arch, westland, geelong, torquato,
# Nearest to for: valencian, crusader, bulldogs, professions, frobenius, opposites, explanatory, arabella,
# Nearest to only: meteorite, townes, mot, factoring, artform, mothman, given, fro,
# Average loss at step 2000: 4.368960
# Average loss at step 4000: 3.866201
# Average loss at step 6000: 3.791965
# Average loss at step 8000: 3.690275
# Average loss at step 10000: 3.619566
# Nearest to two: three, four, five, six, seven, eight, zero, nine,
# Nearest to however: sinning, hasdrubal, unsurprising, latvia, monza, unspeakable, bouillon, reality,
# Nearest to known: disparaging, chih, interbreed, well, hellfire, leagues, pluralistic, ladder,
# Nearest to as: by, after, heuss, livelihoods, hermione, supergroup, reproduce, tracking,
# Nearest to is: was, are, has, taxi, nephropathy, surpassed, by, skynyrd,
# Nearest to the: a, its, this, his, their, prasad, an, subcontinent,
# Nearest to has: had, have, was, is, relaunched, cogent, reverting, zoom,
# Nearest to up: product, undeclared, heathland, asceticism, piloted, holiday, magnificence, whales,
# Nearest to time: guerrero, thought, css, colspan, catalana, appropriated, analogs, hobbit,
# Nearest to at: in, oblivious, on, tachyon, rearranging, monthly, happiest, differently,
# Nearest to not: it, also, they, often, who, dropouts, be, auditory,
# Nearest to d: catalyst, b, situational, and, vows, cuba, cadmium, listerine,
# Nearest to were: are, was, have, do, prejudicial, generally, psychological, mesoplodon,
# Nearest to american: carcinoma, dear, flair, poorer, arthur, torquato, nudity, llewelyn,
# Nearest to for: of, vesicles, in, inca, pedals, from, trimmed, against,
# Nearest to only: given, pomona, karabakh, mebyon, libby, saw, motivating, meteorite,
# Average loss at step 12000: 3.600540
# Average loss at step 14000: 3.570355
# Average loss at step 16000: 3.408301
# Average loss at step 18000: 3.454036
# Average loss at step 20000: 3.541140
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to however: but, sinning, landsat, since, and, reality, monza, helped,
# Nearest to known: used, chih, such, disparaging, well, classified, bancroft, hellfire,
# Nearest to as: christchurch, tracking, by, laborious, artifice, nephropathy, aconcagua, exhaustive,
# Nearest to is: was, are, has, be, at, but, were, skynyrd,
# Nearest to the: their, its, this, a, an, his, any, mortensen,
# Nearest to has: had, have, was, is, reverting, relaunched, distinctly, single,
# Nearest to up: heathland, necks, murky, whales, revenue, byelorussian, callous, piloted,
# Nearest to time: css, retrospectively, hippocampus, hobbit, archeology, volunteering, ornamental, catalana,
# Nearest to at: in, from, on, when, is, dismissed, near, ligatures,
# Nearest to not: also, often, they, it, auditory, reunited, to, calves,
# Nearest to d: b, blacki, situational, catalyst, cadmium, vows, georgian, cuba,
# Nearest to were: are, was, had, have, metzger, be, is, by,
# Nearest to american: british, carcinoma, dear, flair, french, adipose, and, jive,
# Nearest to for: with, by, against, of, vesicles, throughout, in, upon,
# Nearest to only: given, pomona, spill, transformative, wherefore, allow, sells, mebyon,
# Average loss at step 22000: 3.495710
# Average loss at step 24000: 3.488156
# Average loss at step 26000: 3.479966
# Average loss at step 28000: 3.479760
# Average loss at step 30000: 3.504086
# Nearest to two: four, three, one, five, seven, six, eight, nine,
# Nearest to however: but, although, and, where, sinning, when, while, methodist,
# Nearest to known: used, well, such, chih, described, regarded, hellfire, classified,
# Nearest to as: laborious, abjad, debug, reproduce, hinge, christchurch, exhaustive, rulebook,
# Nearest to is: was, has, are, became, although, be, were, includes,
# Nearest to the: his, their, its, some, any, her, donates, this,
# Nearest to has: had, have, is, was, reverting, dieppe, nonsensical, distinctly,
# Nearest to up: heathland, whales, murky, byelorussian, alphonso, packet, lust, callous,
# Nearest to time: archeology, hr, year, hobbit, period, shapiro, yaw, css,
# Nearest to at: in, during, on, when, after, near, un, happiest,
# Nearest to not: they, often, it, auditory, this, also, reunited, still,
# Nearest to d: b, blacki, catalyst, situational, h, cadmium, cuba, cameraman,
# Nearest to were: are, was, had, have, metzger, overwhelmed, is, been,
# Nearest to american: british, adipose, carcinoma, dear, flair, italian, canadian, vinnie,
# Nearest to for: schuster, after, falsified, when, against, with, vesicles, styx,
# Nearest to only: allow, given, landon, gut, eastwards, not, prussian, pomona,
# Average loss at step 32000: 3.499345
# Average loss at step 34000: 3.494242
# Average loss at step 36000: 3.457609
# Average loss at step 38000: 3.302267
# Average loss at step 40000: 3.430470
# Nearest to two: three, four, six, five, seven, eight, one, nine,
# Nearest to however: but, although, that, while, though, bc, so, where,
# Nearest to known: such, used, well, described, defined, regarded, chih, classified,
# Nearest to as: arf, debug, laborious, hinge, tracking, reproduce, abjad, allergic,
# Nearest to is: was, are, has, be, if, hairy, becomes, became,
# Nearest to the: a, their, its, his, this, any, each, weezer,
# Nearest to has: had, have, was, is, reverting, dieppe, having, since,
# Nearest to up: him, out, them, heathland, together, byelorussian, necks, whales,
# Nearest to time: year, round, period, hr, archeology, way, appropriated, hobbit,
# Nearest to at: during, near, in, on, un, alaskan, angular, retorted,
# Nearest to not: they, often, still, auditory, usually, also, always, t,
# Nearest to d: b, situational, blacki, catalyst, h, raj, j, cadmium,
# Nearest to were: are, have, was, had, metzger, been, worldview, while,
# Nearest to american: carcinoma, british, australian, italian, french, dear, nasals, stamens,
# Nearest to for: in, against, after, of, workforce, banjos, flightless, nav,
# Nearest to only: detained, nurturing, primarily, lattices, allow, it, prussian, closest,
# Average loss at step 42000: 3.433046
# Average loss at step 44000: 3.456092
# Average loss at step 46000: 3.449317
# Average loss at step 48000: 3.359648
# Average loss at step 50000: 3.386737
# Nearest to two: three, four, six, five, seven, eight, one, zero,
# Nearest to however: but, although, while, that, when, though, where, bc,
# Nearest to known: used, such, well, regarded, described, defined, chih, classified,
# Nearest to as: abjad, arf, became, laborious, hinge, huguenots, monism, shamanistic,
# Nearest to is: was, has, are, became, be, although, includes, lyapunov,
# Nearest to the: its, their, this, a, some, clearances, his, many,
# Nearest to has: had, have, was, is, having, since, taliaferro, surpassed,
# Nearest to up: him, out, together, them, off, whales, down, heathland,
# Nearest to time: year, way, period, archeology, round, appropriated, hobbit, day,
# Nearest to at: during, near, in, tachyon, retorted, informs, alaskan, contractile,
# Nearest to not: generally, steadily, they, usually, t, always, still, auditory,
# Nearest to d: b, r, situational, h, blacki, e, j, p,
# Nearest to were: are, was, have, had, been, be, metzger, failed,
# Nearest to american: british, carcinoma, nasals, english, australian, italian, french, stamens,
# Nearest to for: against, while, vesicles, on, falsified, professions, during, opposites,
# Nearest to only: detained, therefore, prophet, adipose, select, arguably, claiming, allow,
# Average loss at step 52000: 3.435878
# Average loss at step 54000: 3.428102
# Average loss at step 56000: 3.438703
# Average loss at step 58000: 3.396766
# Average loss at step 60000: 3.392545
# Nearest to two: three, four, five, one, eight, six, seven, zero,
# Nearest to however: but, although, though, that, bc, while, methodist, since,
# Nearest to known: used, such, regarded, described, apply, well, defined, classified,
# Nearest to as: abjad, when, hinge, became, laborious, debug, constructor, eigenvalue,
# Nearest to is: was, are, has, although, does, but, rangers, be,
# Nearest to the: their, its, this, a, some, any, these, peacock,
# Nearest to has: had, have, was, is, having, surpassed, distinctly, since,
# Nearest to up: out, together, him, off, down, them, heathland, whales,
# Nearest to time: archeology, saginaw, round, year, way, hobbit, satisfactory, period,
# Nearest to at: during, in, near, tachyon, under, angular, rearranging, monthly,
# Nearest to not: they, usually, generally, now, still, there, you, granted,
# Nearest to d: b, r, h, c, l, j, blacki, situational,
# Nearest to were: are, was, have, including, although, had, been, metzger,
# Nearest to american: british, australian, italian, english, european, nasals, carcinoma, indian,
# Nearest to for: including, of, against, when, ngel, and, enrollments, borden,
# Nearest to only: detained, select, still, negroes, quantifying, prophet, adipose, arguably,
# Average loss at step 62000: 3.244254
# Average loss at step 64000: 3.253543
# Average loss at step 66000: 3.409062
# Average loss at step 68000: 3.393035
# Average loss at step 70000: 3.358472
# Nearest to two: three, four, six, one, five, seven, eight, zero,
# Nearest to however: but, although, that, though, while, when, since, where,
# Nearest to known: used, such, regarded, defined, classified, described, well, chih,
# Nearest to as: when, debug, constructor, iroquois, laborious, bader, martian, arf,
# Nearest to is: was, has, are, be, becomes, became, although, does,
# Nearest to the: its, their, this, a, any, these, comit, another,
# Nearest to has: had, have, is, was, since, having, surpassed, historically,
# Nearest to up: off, out, them, together, him, down, savile, byelorussian,
# Nearest to time: saginaw, archeology, way, round, satisfactory, before, hobbit, appropriated,
# Nearest to at: in, during, near, on, samaritan, within, for, landis,
# Nearest to not: generally, now, still, usually, always, granted, probably, steadily,
# Nearest to d: b, n, h, r, j, f, courteous, leo,
# Nearest to were: are, was, have, had, be, been, metzger, became,
# Nearest to american: british, australian, italian, nasals, dear, irish, fiction, america,
# Nearest to for: in, against, including, without, vesicles, while, on, workforce,
# Nearest to only: select, clearly, still, practicing, negroes, completely, detained, adorno,
# Average loss at step 72000: 3.375115
# Average loss at step 74000: 3.346961
# Average loss at step 76000: 3.313721
# Average loss at step 78000: 3.348128
# Average loss at step 80000: 3.382377
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Nearest to however: although, but, though, that, while, where, when, methodist,
# Nearest to known: used, such, regarded, defined, classified, described, opposed, referred,
# Nearest to as: particularly, abort, constructor, flourish, after, childish, patria, abjad,
# Nearest to is: was, has, are, became, although, refers, includes, becomes,
# Nearest to the: its, their, a, this, mortensen, his, micas, attu,
# Nearest to has: had, have, is, having, was, since, although, distinctly,
# Nearest to up: out, off, them, together, down, him, savile, byelorussian,
# Nearest to time: year, round, archeology, season, hobbit, saginaw, appropriated, category,
# Nearest to at: in, near, during, on, rearranging, happiest, samaritan, unemployment,
# Nearest to not: generally, still, always, usually, often, typically, probably, almost,
# Nearest to d: b, raj, h, p, j, r, courteous, diverges,
# Nearest to were: are, was, have, had, been, became, those, be,
# Nearest to american: british, scottish, australian, irish, italian, nasals, german, asymptomatic,
# Nearest to for: vesicles, including, flightless, falsified, residency, jenkins, when, while,
# Nearest to only: negroes, select, adipose, last, practicing, player, first, adorno,
# Average loss at step 82000: 3.406710
# Average loss at step 84000: 3.409622
# Average loss at step 86000: 3.389353
# Average loss at step 88000: 3.359227
# Average loss at step 90000: 3.363602
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to however: but, although, that, though, while, since, during, where,
# Nearest to known: used, such, regarded, opposed, described, called, classified, referred,
# Nearest to as: abjad, aconcagua, iroquois, hook, bader, became, contemporaries, socket,
# Nearest to is: was, has, are, although, becomes, seems, be, does,
# Nearest to the: its, his, their, each, this, any, a, manfred,
# Nearest to has: had, have, is, was, having, since, although, requires,
# Nearest to up: out, off, together, them, down, him, back, away,
# Nearest to time: saginaw, season, year, appropriated, before, malthusian, landform, hobbit,
# Nearest to at: during, near, on, under, in, while, marketable, angular,
# Nearest to not: still, generally, we, probably, reunited, always, almost, already,
# Nearest to d: b, raj, bonded, nosferatu, shroud, j, ag, diverges,
# Nearest to were: are, had, was, have, while, although, these, been,
# Nearest to american: british, italian, scottish, australian, brazilian, french, nasals, spanish,
# Nearest to for: including, against, vesicles, of, while, during, after, by,
# Nearest to only: no, clearly, negroes, select, practicing, adipose, freely, therefore,
# Average loss at step 92000: 3.397279
# Average loss at step 94000: 3.253863
# Average loss at step 96000: 3.359942
# Average loss at step 98000: 3.245254
# Average loss at step 100000: 3.357336
# Nearest to two: three, five, four, six, seven, one, eight, zero,
# Nearest to however: but, although, that, though, where, which, while, since,
# Nearest to known: such, regarded, used, described, opposed, possible, defined, classified,
# Nearest to as: particularly, aconcagua, abjad, replicate, patria, js, huguenots, christchurch,
# Nearest to is: was, has, became, becomes, are, seems, be, had,
# Nearest to the: their, its, his, a, your, some, each, my,
# Nearest to has: had, have, is, was, having, since, distinctly, includes,
# Nearest to up: out, off, together, them, him, down, back, away,
# Nearest to time: year, periods, round, way, kind, direction, season, appropriated,
# Nearest to at: during, near, on, after, in, informs, dale, haunt,
# Nearest to not: still, generally, always, considered, almost, they, also, usually,
# Nearest to d: b, h, blacki, airshow, ja, c, situational, r,
# Nearest to were: are, was, have, had, these, those, although, include,
# Nearest to american: british, scottish, italian, australian, dear, french, canadian, brazilian,
# Nearest to for: when, against, including, vesicles, after, while, if, before,
# Nearest to only: freely, clearly, no, adipose, tunnels, negroes, exactly, actually,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
